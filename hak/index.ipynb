# %%
import pandas as pd
import os
os.chdir("C:/Users/ahahm/Desktop/machine learning/hak")
print(os.getcwd())
# Out:
# C:\Users\ahahm\Desktop\machine learning\hak

# %%
df1=pd.read_csv('agua.csv')
df1.sample(1)
# Out:
#             FECHA  AGUA_ACTUAL   ID
# 99324  2018-10-09         44.0  181

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683445 entries, 0 to 683444
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   FECHA        683445 non-null  object
#  1   AGUA_ACTUAL  683445 non-null  float64
#  2   ID           683445 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 15.6+ MB

# %%
df1['FECHA'] = pd.to_datetime(df1['FECHA'], errors='coerce')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683445 entries, 0 to 683444
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   FECHA        683445 non-null  datetime64[ns]
#  1   AGUA_ACTUAL  683445 non-null  float64
#  2   ID           683445 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 15.6 MB

# %%
print(df1['FECHA'].head(10))  # عرض أول 10 قيم في عمود FECHA
# Out:
# 0   2012-09-04
# 1   2012-10-23
# 2   2012-11-27
# 3   1991-01-22
# 4   1991-05-21
# 5   1991-09-24
# 6   1991-10-15
# 7   1991-11-26
# 8   1991-12-10
# 9   1991-12-31
# Name: FECHA, dtype: datetime64[ns]

# %%
df1[df1['AGUA_ACTUAL']==0]
# Out:
#             FECHA  AGUA_ACTUAL   ID
# 144    1988-01-12          0.0   19
# 147    1988-07-19          0.0   19
# 148    1988-09-06          0.0   19
# 149    1988-11-29          0.0   19
# 150    1989-02-28          0.0   19
# ...           ...          ...  ...
# 683394 1994-07-19          0.0  743
# 683395 1994-10-18          0.0  743
# 683414 1997-11-04          0.0  743
# 683427 2000-03-28          0.0  743
# 683438 2001-11-13          0.0  743
#
# [27273 rows x 3 columns]

# %%
df1[df1['AGUA_ACTUAL'].isnull()]
# Out:
# Empty DataFrame
# Columns: [FECHA, AGUA_ACTUAL, ID]
# Index: []

# %%
d396=df1[(df1['ID'] == 396) & (df1['AGUA_ACTUAL'].notnull())]

d396
# Out:
#             FECHA  AGUA_ACTUAL   ID
# 91348  2010-09-14         17.0  396
# 91349  2010-11-23         15.0  396
# 91350  2011-03-15         24.0  396
# 91351  2011-04-05         35.0  396
# 91352  2011-10-18         11.0  396
# ...           ...          ...  ...
# 678986 2019-02-26         18.0  396
# 678987 2021-07-20         23.0  396
# 678988 2021-08-31         13.0  396
# 678989 2021-09-28         12.0  396
# 678990 2021-10-26         10.0  396
#
# [945 rows x 3 columns]

# %%
d396=df1[(df1['ID'] == 396) & (df1['AGUA_ACTUAL'].notnull())].max()
d396
# Out:
# FECHA          2024-09-24 00:00:00
# AGUA_ACTUAL                   36.0
# ID                             396
# dtype: object

# %%
d396_null=df1[(df1['ID'] == 396) & (df1['AGUA_ACTUAL'].isnull())]
d396_null
# Out:
# Empty DataFrame
# Columns: [FECHA, AGUA_ACTUAL, ID]
# Index: []

# %%
df1.dropna(subset=['ID', 'AGUA_ACTUAL'], inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683445 entries, 0 to 683444
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   FECHA        683445 non-null  datetime64[ns]
#  1   AGUA_ACTUAL  683445 non-null  float64
#  2   ID           683445 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 15.6 MB

# %%
df2=pd.read_csv('embalsesUTF8.csv')
df2.sample(9)
# Out:
#       ID          AMBITO_NOMBRE EMBALSE_NOMBRE  AGUA_TOTAL  ELECTRICO_FLAG
# 106  203           GUADALQUIVIR     BOLERA, LA        54.0               0
# 267  509  CANTÁBRICO OCCIDENTAL     ALFILORIOS         9.0               0
# 59   120             MIÑO - SIL     EDRADA-MAO        15.0               1
# 71   142                   EBRO       CAMARASA       163.0               1
# 38    74             MIÑO - SIL          VELLE        17.0               1
# 198  384             MIÑO - SIL  SANTA EULALIA        10.0               1
# 21    46                   EBRO        CALANDA        54.0               0
# 104  196                   EBRO    MONTEARAGÓN        52.0               0
# 344  638                  DUERO          RIAÑO       664.0               0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              401 non-null    int64
#  1   AMBITO_NOMBRE   401 non-null    object
#  2   EMBALSE_NOMBRE  401 non-null    object
#  3   AGUA_TOTAL      400 non-null    float64
#  4   ELECTRICO_FLAG  401 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 15.8+ KB

# %%
df2['AMBITO_NOMBRE'] = df2['AMBITO_NOMBRE'].astype(pd.StringDtype())
df2['EMBALSE_NOMBRE'] = df2['EMBALSE_NOMBRE'].astype(pd.StringDtype())

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              401 non-null    int64
#  1   AMBITO_NOMBRE   401 non-null    string
#  2   EMBALSE_NOMBRE  401 non-null    string
#  3   AGUA_TOTAL      400 non-null    float64
#  4   ELECTRICO_FLAG  401 non-null    int64
# dtypes: float64(1), int64(2), string(2)
# memory usage: 15.8 KB

# %%
df2[df2['AGUA_TOTAL'].isnull()]
# Out:
#       ID AMBITO_NOMBRE EMBALSE_NOMBRE  AGUA_TOTAL  ELECTRICO_FLAG
# 206  396          EBRO        PAJARES         NaN               0

# %%
df2.loc[df2['AGUA_TOTAL'].isnull(), 'AGUA_TOTAL'] = d396['AGUA_ACTUAL']
df2[df2['ID'] == 396]
# Out:
#       ID AMBITO_NOMBRE EMBALSE_NOMBRE  AGUA_TOTAL  ELECTRICO_FLAG
# 206  396          EBRO        PAJARES        36.0               0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              401 non-null    int64
#  1   AMBITO_NOMBRE   401 non-null    string
#  2   EMBALSE_NOMBRE  401 non-null    string
#  3   AGUA_TOTAL      401 non-null    float64
#  4   ELECTRICO_FLAG  401 non-null    int64
# dtypes: float64(1), int64(2), string(2)
# memory usage: 15.8 KB

# %%
df2[['AMBITO_NOMBRE', 'EMBALSE_NOMBRE']] = df2[['AMBITO_NOMBRE', 'EMBALSE_NOMBRE']].apply(lambda x: x.str.lower())

# %%
df3 = pd.read_csv('listadoUTF8-3.tsv', sep='\t')
df3.sample(1)
# Out:
#       CODIGO        NOMBRE                 EMBALSE             X  \
# 319  2370010  SANTA TERESA  Santa Teresa Reservoir  40,666865961
#
#                      Y DEMARC       CAUCE  \
# 319  -5,60128066699997  DUERO  RÍO TORMES
#
#                                               GOOGLE  \
# 319  https://www.google.com/search?kgmid=/g/120z6y1r
#
#                                       OPENSTREETMAP  \
# 319  https://www.openstreetmap.org/relation/4473782
#
#                                    WIKIDATA  PROVINCIA             CCAA  \
# 319  https://www.wikidata.org/wiki/Q5830568  Salamanca  Castilla y León
#
#                                                 TIPO COTA_CORON ALT_CIMIEN  \
# 319  Presa de fábrica de gravedad (hormigón vibrado)      887,2         60
#
#                                                INFORME
# 319  https://sig.mapama.gob.es/WebServices/clientew...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CODIGO         367 non-null    int64
#  1   NOMBRE         367 non-null    object
#  2   EMBALSE        367 non-null    object
#  3   X              367 non-null    object
#  4   Y              367 non-null    object
#  5   DEMARC         367 non-null    object
#  6   CAUCE          359 non-null    object
#  7   GOOGLE         115 non-null    object
#  8   OPENSTREETMAP  36 non-null     object
#  9   WIKIDATA       187 non-null    object
#  10  PROVINCIA      367 non-null    object
#  11  CCAA           367 non-null    object
#  12  TIPO           367 non-null    object
#  13  COTA_CORON     184 non-null    object
#  14  ALT_CIMIEN     184 non-null    object
#  15  INFORME        367 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 46.0+ KB

# %%
df3['COTA_CORON'] = df3['COTA_CORON'].str.replace(',', '.', regex=False)
df3['ALT_CIMIEN'] = df3['ALT_CIMIEN'].str.replace(',', '.', regex=False)

# %%
df3['CODIGO'] = df3['CODIGO'].astype('int64')  # يبقى int64
df3['NOMBRE'] = df3['NOMBRE'].astype(pd.StringDtype())  # تحويل إلى string
df3['EMBALSE'] = df3['EMBALSE'].astype(pd.StringDtype())  # تحويل إلى string
df3['DEMARC'] = df3['DEMARC'].astype(pd.StringDtype())  # تحويل إلى string
df3['CAUCE'] = df3['CAUCE'].astype(pd.StringDtype())  # تحويل إلى string
df3['GOOGLE'] = df3['GOOGLE'].astype(pd.StringDtype())  # تحويل إلى string
df3['OPENSTREETMAP'] = df3['OPENSTREETMAP'].astype(pd.StringDtype())  # تحويل إلى string
df3['WIKIDATA'] = df3['WIKIDATA'].astype(pd.StringDtype())  # تحويل إلى string
df3['PROVINCIA'] = df3['PROVINCIA'].astype(pd.StringDtype())  # تحويل إلى string
df3['CCAA'] = df3['CCAA'].astype(pd.StringDtype())  # تحويل إلى string
df3['TIPO'] = df3['TIPO'].astype(pd.StringDtype())  # تحويل إلى string
df3['INFORME'] = df3['INFORME'].astype(pd.StringDtype())  # تحويل إلى string
df3['COTA_CORON'] = df3['COTA_CORON'].astype('float64')  # يبقى int64
df3['ALT_CIMIEN'] = df3['ALT_CIMIEN'].astype('float64')
df3['X'] = df3['X'].astype(pd.StringDtype())
df3['Y'] = df3['Y'].astype(pd.StringDtype())

df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CODIGO         367 non-null    int64
#  1   NOMBRE         367 non-null    string
#  2   EMBALSE        367 non-null    string
#  3   X              367 non-null    string
#  4   Y              367 non-null    string
#  5   DEMARC         367 non-null    string
#  6   CAUCE          359 non-null    string
#  7   GOOGLE         115 non-null    string
#  8   OPENSTREETMAP  36 non-null     string
#  9   WIKIDATA       187 non-null    string
#  10  PROVINCIA      367 non-null    string
#  11  CCAA           367 non-null    string
#  12  TIPO           367 non-null    string
#  13  COTA_CORON     184 non-null    float64
#  14  ALT_CIMIEN     184 non-null    float64
#  15  INFORME        367 non-null    string
# dtypes: float64(2), int64(1), string(13)
# memory usage: 46.0 KB

# %%
df3['X'] = df3['X'].str.replace(',', '.', regex=False)
df3['Y'] = df3['Y'].str.replace(',', '.', regex=False)

# %%
df3['X'] = df3['X'].astype('float64')
df3['Y'] = df3['Y'].astype('float64')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CODIGO         367 non-null    int64
#  1   NOMBRE         367 non-null    string
#  2   EMBALSE        367 non-null    string
#  3   X              367 non-null    float64
#  4   Y              367 non-null    float64
#  5   DEMARC         367 non-null    string
#  6   CAUCE          359 non-null    string
#  7   GOOGLE         115 non-null    string
#  8   OPENSTREETMAP  36 non-null     string
#  9   WIKIDATA       187 non-null    string
#  10  PROVINCIA      367 non-null    string
#  11  CCAA           367 non-null    string
#  12  TIPO           367 non-null    string
#  13  COTA_CORON     184 non-null    float64
#  14  ALT_CIMIEN     184 non-null    float64
#  15  INFORME        367 non-null    string
# dtypes: float64(4), int64(1), string(11)
# memory usage: 46.0 KB

# %%
df3[df3.select_dtypes(include=['string']).columns] = df3.select_dtypes(include=['string']).apply(lambda x: x.str.lower())

# %%
names_to_check = pd.concat([df2['EMBALSE_NOMBRE'], df2['AMBITO_NOMBRE']])

filtered_samples = df3[df3['NOMBRE'].isin(df2['AMBITO_NOMBRE']) | df3['EMBALSE'].isin(df2['EMBALSE_NOMBRE'])]
filtered_samples
# Out:
#       CODIGO          NOMBRE         EMBALSE          X         Y  \
# 0    9250031        sallente        sallente  42.500371  0.991460
# 7    4060047        brovales        brovales  38.345278 -6.695880
# 14   3450045      castro, el      castro, el  39.806445 -3.752950
# 17   5230007         zocueca         zocueca  38.095562 -3.831098
# 21   4130017     castilseras     castilseras  38.738909 -4.801346
# ..       ...             ...             ...        ...       ...
# 323  9390001            ebro  ebro reservoir  42.969947 -4.051694
# 330  9220076       santa ana       santa ana  41.882506  0.580850
# 331  5230036  fernandina, la  fernandina, la  38.179646 -3.570224
# 361  8460021       contreras       contreras  39.543563 -1.503163
# 362  8460022       contreras       contreras  39.543223 -1.510327
#
#            DEMARC                    CAUCE  \
# 0            ebro       barranc de la lora
# 7        guadiana       arroyo de brovales
# ...

# %%
df3[df3['CODIGO'].isnull()]
# Out:
# Empty DataFrame
# Columns: [CODIGO, NOMBRE, EMBALSE, X, Y, DEMARC, CAUCE, GOOGLE, OPENSTREETMAP, WIKIDATA, PROVINCIA, CCAA, TIPO, COTA_CORON, ALT_CIMIEN, INFORME]
# Index: []

# %%
merged_df = pd.merge(df3, df2,  left_on='NOMBRE', right_on='EMBALSE_NOMBRE')
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CODIGO          224 non-null    int64
#  1   NOMBRE          224 non-null    string
#  2   EMBALSE         224 non-null    string
#  3   X               224 non-null    float64
#  4   Y               224 non-null    float64
#  5   DEMARC          224 non-null    string
#  6   CAUCE           222 non-null    string
#  7   GOOGLE          83 non-null     string
#  8   OPENSTREETMAP   26 non-null     string
#  9   WIKIDATA        124 non-null    string
#  10  PROVINCIA       224 non-null    string
#  11  CCAA            224 non-null    string
#  12  TIPO            224 non-null    string
#  13  COTA_CORON      112 non-null    float64
#  14  ALT_CIMIEN      112 non-null    float64
#  15  INFORME         224 non-null    string
#  16  ID              224 non-null    int64
# ...

# %%
merged_df.sample(9)
# Out:
#       CODIGO            NOMBRE                EMBALSE          X         Y  \
# 101  3280003       riosequillo  riosequillo reservoir  40.984601 -3.648254
# 95   3100060    rivera de gata         rivera de gata  40.136397 -6.638712
# 56   4060102           montijo                montijo  38.923661 -6.428681
# 154  5410036            huesna                 huesna  37.769635 -5.685214
# 54   2340015           cervera                cervera  42.866051 -4.527681
# 103  3190011            beleña                 beleña  40.933865 -3.196007
# 78   5180012          cubillas    embalse de cubillas  37.274509 -3.683171
# 110  3190029          vado, el      el vado reservoir  41.002339 -3.296259
# 120  2240009  casares de arbas       casares de arbas  42.927529 -5.759134
#
#            DEMARC                    CAUCE  \
# 101          tajo               río lozoya
# 95           tajo           rivera de gata
# 56       guadiana             rio guadiana
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CODIGO          224 non-null    int64
#  1   NOMBRE          224 non-null    string
#  2   EMBALSE         224 non-null    string
#  3   X               224 non-null    float64
#  4   Y               224 non-null    float64
#  5   DEMARC          224 non-null    string
#  6   CAUCE           222 non-null    string
#  7   GOOGLE          83 non-null     string
#  8   OPENSTREETMAP   26 non-null     string
#  9   WIKIDATA        124 non-null    string
#  10  PROVINCIA       224 non-null    string
#  11  CCAA            224 non-null    string
#  12  TIPO            224 non-null    string
#  13  COTA_CORON      112 non-null    float64
#  14  ALT_CIMIEN      112 non-null    float64
#  15  INFORME         224 non-null    string
#  16  ID              224 non-null    int64
# ...

# %%
filtered_df1 = df1[df1['ID'].isin(merged_df['ID'])]
filtered_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 364285 entries, 113 to 683326
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   FECHA        364285 non-null  datetime64[ns]
#  1   AGUA_ACTUAL  364285 non-null  float64
#  2   ID           364285 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 11.1 MB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683445 entries, 0 to 683444
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   FECHA        683445 non-null  datetime64[ns]
#  1   AGUA_ACTUAL  683445 non-null  float64
#  2   ID           683445 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 15.6 MB

# %%
basic_columns = ['ID', 'AMBITO_NOMBRE', 'EMBALSE_NOMBRE', 'AGUA_TOTAL', 'ELECTRICO_FLAG', 'CODIGO', 'NOMBRE', 'EMBALSE', 'X', 'Y', 'DEMARC', 'PROVINCIA', 'CCAA', 'TIPO', 'INFORME']
secondary_columns = ['ID', 'CAUCE', 'GOOGLE', 'OPENSTREETMAP', 'WIKIDATA', 'COTA_CORON', 'ALT_CIMIEN']

# إنشاء الجدول الأول (المعلومات الأساسية)
basic_info_df = merged_df[basic_columns]

# إنشاء الجدول الثاني (المعلومات الثانوية)
secondary_info_df = merged_df[secondary_columns]

# %%
basic_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              224 non-null    int64
#  1   AMBITO_NOMBRE   224 non-null    string
#  2   EMBALSE_NOMBRE  224 non-null    string
#  3   AGUA_TOTAL      224 non-null    float64
#  4   ELECTRICO_FLAG  224 non-null    int64
#  5   CODIGO          224 non-null    int64
#  6   NOMBRE          224 non-null    string
#  7   EMBALSE         224 non-null    string
#  8   X               224 non-null    float64
#  9   Y               224 non-null    float64
#  10  DEMARC          224 non-null    string
#  11  PROVINCIA       224 non-null    string
#  12  CCAA            224 non-null    string
#  13  TIPO            224 non-null    string
#  14  INFORME         224 non-null    string
# dtypes: float64(3), int64(3), string(9)
# memory usage: 26.4 KB

# %%
secondary_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             224 non-null    int64
#  1   CAUCE          222 non-null    string
#  2   GOOGLE         83 non-null     string
#  3   OPENSTREETMAP  26 non-null     string
#  4   WIKIDATA       124 non-null    string
#  5   COTA_CORON     112 non-null    float64
#  6   ALT_CIMIEN     112 non-null    float64
# dtypes: float64(2), int64(1), string(4)
# memory usage: 12.4 KB

# %%
from sqlalchemy import create_engine

# استخدام PyMySQL
engine = create_engine('mysql+pymysql://root:@localhost:3306/hakathon')

# %%
basic_info_df.to_sql('basic_info', con=engine, if_exists='replace', index=False)
secondary_info_df.to_sql('secondary_info', con=engine, if_exists='replace', index=False)
df1.to_sql('agua', con=engine, if_exists='replace', index=False)
# Out:
# 683445
